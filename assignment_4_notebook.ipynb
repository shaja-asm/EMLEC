# %% [markdown]
# <a href="https://colab.research.google.com/github/shaja-asm/EMLEC/blob/dev/assignment_4_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 4 - TinyML HelloWorld - Section 1
# Based on the **hello_world** example from [TensorFlow Lite for MicroControllers](https://github.com/tensorflow/tflite-micro/tree/main/tensorflow/lite/micro/examples/hello_world).
#
# © SkillSurf 2024

# %% [markdown]
# ## Introduction
#
# In this section you will train a Tensorflow model to a set of sinusoidal data. First you will synthesize the data to mimic a sine wave. Then you can build your own tensorflow model and fit the model to the generated data. Start by importing the relevant modules.

# %% [markdown]
# ## Import modules

# %%
# Import Tensorflow and NumPy
# Set random seed to get reproducible results
import numpy as np
np.random.seed(1)

import tensorflow as tf
tf.random.set_seed(1)

# %%
import os
from tensorflow import keras
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ##  Create the Dataset
#
# You can use NumPy to generate a sinewave data and add some gaussian noise to make the data more realistic. The dataset will consist of 1000 datapoints (x-values) and relevant y-values. The following code creates a sine wave dataset.

# %%
# Number of sample datapoints
SAMPLES = 1000

# Generate a uniformly distributed set of random numbers in the range from
# 0 to 2π, which covers a complete sine wave oscillation
x_values = np.random.uniform(
    low=0, high=2*math.pi, size=SAMPLES).astype(np.float32)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

# Calculate the corresponding sine values
y_values = np.sin(x_values).astype(np.float32)

# Plot the data. The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# Next add noise to the data to make the data more realistic. (In real-life the data we obtain usually get contaminated by different kinds of noise.)

# %%
# Add a small random number to each y value
y_values += 0.1 * np.random.randn(*y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ## Pre-process data (Graded)
#
# The dataset has been given, now you will have to split this dataset into train, validation and test subsets. The following table shows the split ratio you should be using.
#
# | Split | Percentage |
# |----------|----------|
# | Train | 60% |
# | Validation | 20% |
# | Test | 20% |
#
# You may use the `np.split()` function for obtaining 3 splits of data from one line of code. You have to provide the indiced of points which the dataset is divided. The second argument to `np.split()` is an array of indices where the data will be split. We provide two indices, so the data will be divided into three chunks. For more clarification look into the documentation of [np.split()](https://numpy.org/doc/stable/reference/generated/numpy.split.html).
#
#
# ### Exercise 1
# Complete the code below to split the data accordingly and plot all three splits in the same plot.

# %%
# Define the indices where the dataset will get chopped (TODO)
TRAIN_SPLIT = int(0.6 * SAMPLES)
VALIDATION_SPLIT = int(0.8 * SAMPLES)

# Use np.split to chop the data into three parts (TODO)
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, VALIDATION_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, VALIDATION_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES

# Plot the data in each partition in different colors
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'g.', label="Validate")
plt.legend()
plt.show()

# %% [markdown]
# ## Build the Model (Graded)
#
# You have successfully pre-processed the dataset. Next you will have to define build the Tensorflow model using Keras. You may use the Tensorflow Keras Sequential API. Please refer to the official [Keras documentation](https://www.tensorflow.org/api_docs/python/tf/keras/layers) for further information. Use the below architecture to design your the model.
#
# - Input layer
# - 2 Dense layers each consisting of 16 hidden units and ReLU activation - [keras.layers.Dense()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)
# - Output layer with 1 unit
#
# ### Exercise 2
# Design the sequential model according to the specifications above.

# %%
# Define the model using the Keras API (TODO)
model = keras.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(1,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1)
])

# %% [markdown]
# Now that you have created the model, specify the optimizer, loss function and acuracy metrics. Use the below,
#
# - Optimizer: Adam
# - Loss function: Mean Squared Error (MSE)
# - Metric: Mean Absolute Error (MAE)
#
# You may use `model.compile()` and read the [tf.keras.Sequential](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential) documentation for this.
#
# ### Exercise 3
# Set the optimizer and loss function details as specified as above.

# %%
# Compile the model using a standard optimizer and loss function for regression
model.compile(
    optimizer='adam',
    loss='mean_squared_error',
    metrics=['mean_absolute_error']
)

# %%
# Get model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 16)                  │              32 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 321 (1.25 KB)
#  Trainable params: 321 (1.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train the Model (Graded)
#
# Fit the model to the data using `model.fit()`. Train for 500 epochs with a batch size of 64. Use only the train and validation sets during training.
#
# ### Exercise 4
# Fit the model to the data. Keep track of the losses and metrics using `history` object.

# %%
# Fit the model to the data and keep track of losses (TODO)
history = model.fit(
    x_train, y_train,
    epochs=500,
    batch_size=64,
    validation_data=(x_validate, y_validate)
)
# Out:
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.7141 - mean_absolute_error: 0.7511 - val_loss: 0.6183 - val_mean_absolute_error: 0.7166
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5693 - mean_absolute_error: 0.6755 - val_loss: 0.5316 - val_mean_absolute_error: 0.6533
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4997 - mean_absolute_error: 0.6283 - val_loss: 0.4875 - val_mean_absolute_error: 0.6117
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4644 - mean_absolute_error: 0.5966 - val_loss: 0.4589 - val_mean_absolute_error: 0.5880
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4393 - mean_absolute_error: 0.5741 - val_loss: 0.4379 - val_mean_absolute_error: 0.5736
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4207 - mean_absolute_error: 0.5598 - val_loss: 0.4198 - val_mean_absolute_error: 0.5616
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4035 - mean_absolute_error: 0.5470 - val_loss: 0.4026 - val_mean_absolute_error: 0.5504
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3865 - mean_absolute_error: 0.5345 - val_loss: 0.3837 - val_mean_absolute_error: 0.5386
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3686 - mean_absolute_error: 0.5230 - val_loss: 0.3677 - val_mean_absolute_error: 0.5290
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3523 - mean_absolute_error: 0.5112 - val_loss: 0.3504 - val_mean_absolute_error: 0.5166
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3359 - mean_absolute_error: 0.4977 - val_loss: 0.3338 - val_mean_absolute_error: 0.5044
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3202 - mean_absolute_error: 0.4849 - val_loss: 0.3186 - val_mean_absolute_error: 0.4938
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3058 - mean_absolute_error: 0.4742 - val_loss: 0.3043 - val_mean_absolute_error: 0.4839
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2918 - mean_absolute_error: 0.4637 - val_loss: 0.2903 - val_mean_absolute_error: 0.4736
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2783 - mean_absolute_error: 0.4534 - val_loss: 0.2771 - val_mean_absolute_error: 0.4639
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2652 - mean_absolute_error: 0.4434 - val_loss: 0.2643 - val_mean_absolute_error: 0.4541
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2528 - mean_absolute_error: 0.4334 - val_loss: 0.2521 - val_mean_absolute_error: 0.4445
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2410 - mean_absolute_error: 0.4239 - val_loss: 0.2405 - val_mean_absolute_error: 0.4346
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2299 - mean_absolute_error: 0.4149 - val_loss: 0.2298 - val_mean_absolute_error: 0.4248
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2194 - mean_absolute_error: 0.4061 - val_loss: 0.2197 - val_mean_absolute_error: 0.4155
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2097 - mean_absolute_error: 0.3977 - val_loss: 0.2106 - val_mean_absolute_error: 0.4072
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2008 - mean_absolute_error: 0.3899 - val_loss: 0.2021 - val_mean_absolute_error: 0.3993
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1928 - mean_absolute_error: 0.3825 - val_loss: 0.1942 - val_mean_absolute_error: 0.3918
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1854 - mean_absolute_error: 0.3755 - val_loss: 0.1873 - val_mean_absolute_error: 0.3850
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1790 - mean_absolute_error: 0.3691 - val_loss: 0.1812 - val_mean_absolute_error: 0.3785
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1733 - mean_absolute_error: 0.3630 - val_loss: 0.1758 - val_mean_absolute_error: 0.3724
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1684 - mean_absolute_error: 0.3575 - val_loss: 0.1713 - val_mean_absolute_error: 0.3670
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1642 - mean_absolute_error: 0.3522 - val_loss: 0.1674 - val_mean_absolute_error: 0.3620
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1606 - mean_absolute_error: 0.3475 - val_loss: 0.1642 - val_mean_absolute_error: 0.3576
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1575 - mean_absolute_error: 0.3434 - val_loss: 0.1614 - val_mean_absolute_error: 0.3534
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1549 - mean_absolute_error: 0.3397 - val_loss: 0.1590 - val_mean_absolute_error: 0.3496
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1527 - mean_absolute_error: 0.3363 - val_loss: 0.1569 - val_mean_absolute_error: 0.3462
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1509 - mean_absolute_error: 0.3334 - val_loss: 0.1553 - val_mean_absolute_error: 0.3431
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1493 - mean_absolute_error: 0.3308 - val_loss: 0.1538 - val_mean_absolute_error: 0.3403
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1478 - mean_absolute_error: 0.3285 - val_loss: 0.1525 - val_mean_absolute_error: 0.3378
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1466 - mean_absolute_error: 0.3264 - val_loss: 0.1514 - val_mean_absolute_error: 0.3354
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1454 - mean_absolute_error: 0.3244 - val_loss: 0.1503 - val_mean_absolute_error: 0.3332
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1444 - mean_absolute_error: 0.3226 - val_loss: 0.1494 - val_mean_absolute_error: 0.3313
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1434 - mean_absolute_error: 0.3210 - val_loss: 0.1485 - val_mean_absolute_error: 0.3297
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1424 - mean_absolute_error: 0.3195 - val_loss: 0.1476 - val_mean_absolute_error: 0.3281
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1415 - mean_absolute_error: 0.3180 - val_loss: 0.1468 - val_mean_absolute_error: 0.3266
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1405 - mean_absolute_error: 0.3165 - val_loss: 0.1460 - val_mean_absolute_error: 0.3251
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1396 - mean_absolute_error: 0.3150 - val_loss: 0.1452 - val_mean_absolute_error: 0.3236
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1387 - mean_absolute_error: 0.3136 - val_loss: 0.1443 - val_mean_absolute_error: 0.3222
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1378 - mean_absolute_error: 0.3123 - val_loss: 0.1435 - val_mean_absolute_error: 0.3208
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1369 - mean_absolute_error: 0.3109 - val_loss: 0.1427 - val_mean_absolute_error: 0.3194
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1360 - mean_absolute_error: 0.3096 - val_loss: 0.1419 - val_mean_absolute_error: 0.3180
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1351 - mean_absolute_error: 0.3082 - val_loss: 0.1410 - val_mean_absolute_error: 0.3166
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1342 - mean_absolute_error: 0.3068 - val_loss: 0.1402 - val_mean_absolute_error: 0.3153
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1333 - mean_absolute_error: 0.3055 - val_loss: 0.1393 - val_mean_absolute_error: 0.3140
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1324 - mean_absolute_error: 0.3041 - val_loss: 0.1384 - val_mean_absolute_error: 0.3125
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1314 - mean_absolute_error: 0.3027 - val_loss: 0.1375 - val_mean_absolute_error: 0.3112
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1305 - mean_absolute_error: 0.3013 - val_loss: 0.1366 - val_mean_absolute_error: 0.3098
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1295 - mean_absolute_error: 0.2998 - val_loss: 0.1357 - val_mean_absolute_error: 0.3084
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1285 - mean_absolute_error: 0.2984 - val_loss: 0.1347 - val_mean_absolute_error: 0.3069
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1275 - mean_absolute_error: 0.2969 - val_loss: 0.1337 - val_mean_absolute_error: 0.3055
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1265 - mean_absolute_error: 0.2954 - val_loss: 0.1327 - val_mean_absolute_error: 0.3040
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1255 - mean_absolute_error: 0.2940 - val_loss: 0.1317 - val_mean_absolute_error: 0.3026
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1244 - mean_absolute_error: 0.2924 - val_loss: 0.1307 - val_mean_absolute_error: 0.3009
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1233 - mean_absolute_error: 0.2908 - val_loss: 0.1296 - val_mean_absolute_error: 0.2994
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1222 - mean_absolute_error: 0.2892 - val_loss: 0.1285 - val_mean_absolute_error: 0.2978
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1211 - mean_absolute_error: 0.2876 - val_loss: 0.1274 - val_mean_absolute_error: 0.2961
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1200 - mean_absolute_error: 0.2859 - val_loss: 0.1263 - val_mean_absolute_error: 0.2945
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1189 - mean_absolute_error: 0.2843 - val_loss: 0.1252 - val_mean_absolute_error: 0.2929
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1177 - mean_absolute_error: 0.2825 - val_loss: 0.1240 - val_mean_absolute_error: 0.2911
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1165 - mean_absolute_error: 0.2808 - val_loss: 0.1228 - val_mean_absolute_error: 0.2894
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1153 - mean_absolute_error: 0.2790 - val_loss: 0.1216 - val_mean_absolute_error: 0.2876
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1139 - mean_absolute_error: 0.2770 - val_loss: 0.1200 - val_mean_absolute_error: 0.2853
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1121 - mean_absolute_error: 0.2743 - val_loss: 0.1182 - val_mean_absolute_error: 0.2828
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1100 - mean_absolute_error: 0.2713 - val_loss: 0.1163 - val_mean_absolute_error: 0.2800
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1077 - mean_absolute_error: 0.2678 - val_loss: 0.1142 - val_mean_absolute_error: 0.2768
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1054 - mean_absolute_error: 0.2641 - val_loss: 0.1121 - val_mean_absolute_error: 0.2733
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1030 - mean_absolute_error: 0.2603 - val_loss: 0.1099 - val_mean_absolute_error: 0.2695
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1005 - mean_absolute_error: 0.2561 - val_loss: 0.1078 - val_mean_absolute_error: 0.2657
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0981 - mean_absolute_error: 0.2520 - val_loss: 0.1057 - val_mean_absolute_error: 0.2619
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0958 - mean_absolute_error: 0.2477 - val_loss: 0.1035 - val_mean_absolute_error: 0.2579
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0935 - mean_absolute_error: 0.2435 - val_loss: 0.1015 - val_mean_absolute_error: 0.2539
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0914 - mean_absolute_error: 0.2393 - val_loss: 0.0995 - val_mean_absolute_error: 0.2501
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0893 - mean_absolute_error: 0.2351 - val_loss: 0.0975 - val_mean_absolute_error: 0.2462
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0873 - mean_absolute_error: 0.2313 - val_loss: 0.0957 - val_mean_absolute_error: 0.2426
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0854 - mean_absolute_error: 0.2276 - val_loss: 0.0939 - val_mean_absolute_error: 0.2392
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0835 - mean_absolute_error: 0.2241 - val_loss: 0.0922 - val_mean_absolute_error: 0.2358
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0818 - mean_absolute_error: 0.2208 - val_loss: 0.0905 - val_mean_absolute_error: 0.2327
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0802 - mean_absolute_error: 0.2175 - val_loss: 0.0889 - val_mean_absolute_error: 0.2297
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0786 - mean_absolute_error: 0.2144 - val_loss: 0.0874 - val_mean_absolute_error: 0.2269
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0771 - mean_absolute_error: 0.2115 - val_loss: 0.0859 - val_mean_absolute_error: 0.2242
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0757 - mean_absolute_error: 0.2088 - val_loss: 0.0845 - val_mean_absolute_error: 0.2217
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0744 - mean_absolute_error: 0.2064 - val_loss: 0.0832 - val_mean_absolute_error: 0.2194
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0731 - mean_absolute_error: 0.2041 - val_loss: 0.0819 - val_mean_absolute_error: 0.2172
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0719 - mean_absolute_error: 0.2020 - val_loss: 0.0806 - val_mean_absolute_error: 0.2151
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0707 - mean_absolute_error: 0.2001 - val_loss: 0.0794 - val_mean_absolute_error: 0.2131
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0696 - mean_absolute_error: 0.1983 - val_loss: 0.0783 - val_mean_absolute_error: 0.2112
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0685 - mean_absolute_error: 0.1966 - val_loss: 0.0771 - val_mean_absolute_error: 0.2094
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0675 - mean_absolute_error: 0.1950 - val_loss: 0.0761 - val_mean_absolute_error: 0.2078
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0665 - mean_absolute_error: 0.1934 - val_loss: 0.0750 - val_mean_absolute_error: 0.2062
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0655 - mean_absolute_error: 0.1919 - val_loss: 0.0739 - val_mean_absolute_error: 0.2048
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0646 - mean_absolute_error: 0.1904 - val_loss: 0.0729 - val_mean_absolute_error: 0.2033
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0637 - mean_absolute_error: 0.1889 - val_loss: 0.0719 - val_mean_absolute_error: 0.2020
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0628 - mean_absolute_error: 0.1876 - val_loss: 0.0709 - val_mean_absolute_error: 0.2007
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0619 - mean_absolute_error: 0.1862 - val_loss: 0.0700 - val_mean_absolute_error: 0.1993
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0610 - mean_absolute_error: 0.1850 - val_loss: 0.0690 - val_mean_absolute_error: 0.1980
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0602 - mean_absolute_error: 0.1837 - val_loss: 0.0681 - val_mean_absolute_error: 0.1967
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0594 - mean_absolute_error: 0.1824 - val_loss: 0.0671 - val_mean_absolute_error: 0.1954
# Epoch 104/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0586 - mean_absolute_error: 0.1812 - val_loss: 0.0662 - val_mean_absolute_error: 0.1941
# Epoch 105/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0578 - mean_absolute_error: 0.1800 - val_loss: 0.0653 - val_mean_absolute_error: 0.1928
# Epoch 106/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0570 - mean_absolute_error: 0.1788 - val_loss: 0.0644 - val_mean_absolute_error: 0.1915
# Epoch 107/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0562 - mean_absolute_error: 0.1776 - val_loss: 0.0635 - val_mean_absolute_error: 0.1903
# Epoch 108/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0555 - mean_absolute_error: 0.1765 - val_loss: 0.0626 - val_mean_absolute_error: 0.1891
# Epoch 109/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0547 - mean_absolute_error: 0.1753 - val_loss: 0.0618 - val_mean_absolute_error: 0.1878
# Epoch 110/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0540 - mean_absolute_error: 0.1741 - val_loss: 0.0609 - val_mean_absolute_error: 0.1865
# Epoch 111/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0533 - mean_absolute_error: 0.1729 - val_loss: 0.0600 - val_mean_absolute_error: 0.1852
# Epoch 112/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0525 - mean_absolute_error: 0.1718 - val_loss: 0.0592 - val_mean_absolute_error: 0.1839
# Epoch 113/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0518 - mean_absolute_error: 0.1707 - val_loss: 0.0583 - val_mean_absolute_error: 0.1827
# Epoch 114/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0511 - mean_absolute_error: 0.1696 - val_loss: 0.0575 - val_mean_absolute_error: 0.1815
# Epoch 115/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0504 - mean_absolute_error: 0.1685 - val_loss: 0.0566 - val_mean_absolute_error: 0.1801
# Epoch 116/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0497 - mean_absolute_error: 0.1673 - val_loss: 0.0558 - val_mean_absolute_error: 0.1788
# Epoch 117/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0490 - mean_absolute_error: 0.1661 - val_loss: 0.0550 - val_mean_absolute_error: 0.1775
# Epoch 118/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0483 - mean_absolute_error: 0.1649 - val_loss: 0.0541 - val_mean_absolute_error: 0.1761
# Epoch 119/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0476 - mean_absolute_error: 0.1637 - val_loss: 0.0533 - val_mean_absolute_error: 0.1747
# Epoch 120/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0469 - mean_absolute_error: 0.1625 - val_loss: 0.0525 - val_mean_absolute_error: 0.1734
# Epoch 121/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0463 - mean_absolute_error: 0.1612 - val_loss: 0.0517 - val_mean_absolute_error: 0.1721
# Epoch 122/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0456 - mean_absolute_error: 0.1601 - val_loss: 0.0509 - val_mean_absolute_error: 0.1708
# Epoch 123/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0450 - mean_absolute_error: 0.1590 - val_loss: 0.0502 - val_mean_absolute_error: 0.1694
# Epoch 124/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0444 - mean_absolute_error: 0.1578 - val_loss: 0.0494 - val_mean_absolute_error: 0.1681
# Epoch 125/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0438 - mean_absolute_error: 0.1567 - val_loss: 0.0487 - val_mean_absolute_error: 0.1669
# Epoch 126/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0432 - mean_absolute_error: 0.1556 - val_loss: 0.0480 - val_mean_absolute_error: 0.1656
# Epoch 127/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0426 - mean_absolute_error: 0.1545 - val_loss: 0.0473 - val_mean_absolute_error: 0.1644
# Epoch 128/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0420 - mean_absolute_error: 0.1534 - val_loss: 0.0466 - val_mean_absolute_error: 0.1632
# Epoch 129/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0414 - mean_absolute_error: 0.1523 - val_loss: 0.0459 - val_mean_absolute_error: 0.1620
# Epoch 130/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0408 - mean_absolute_error: 0.1512 - val_loss: 0.0452 - val_mean_absolute_error: 0.1608
# Epoch 131/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0403 - mean_absolute_error: 0.1502 - val_loss: 0.0445 - val_mean_absolute_error: 0.1597
# Epoch 132/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0397 - mean_absolute_error: 0.1491 - val_loss: 0.0439 - val_mean_absolute_error: 0.1586
# Epoch 133/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0392 - mean_absolute_error: 0.1481 - val_loss: 0.0432 - val_mean_absolute_error: 0.1575
# Epoch 134/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0387 - mean_absolute_error: 0.1470 - val_loss: 0.0426 - val_mean_absolute_error: 0.1565
# Epoch 135/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0382 - mean_absolute_error: 0.1460 - val_loss: 0.0420 - val_mean_absolute_error: 0.1553
# Epoch 136/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0376 - mean_absolute_error: 0.1448 - val_loss: 0.0414 - val_mean_absolute_error: 0.1542
# Epoch 137/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0371 - mean_absolute_error: 0.1438 - val_loss: 0.0408 - val_mean_absolute_error: 0.1532
# Epoch 138/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0366 - mean_absolute_error: 0.1427 - val_loss: 0.0402 - val_mean_absolute_error: 0.1521
# Epoch 139/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0361 - mean_absolute_error: 0.1416 - val_loss: 0.0396 - val_mean_absolute_error: 0.1509
# Epoch 140/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0357 - mean_absolute_error: 0.1406 - val_loss: 0.0390 - val_mean_absolute_error: 0.1498
# Epoch 141/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0352 - mean_absolute_error: 0.1395 - val_loss: 0.0384 - val_mean_absolute_error: 0.1487
# Epoch 142/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0347 - mean_absolute_error: 0.1385 - val_loss: 0.0379 - val_mean_absolute_error: 0.1476
# Epoch 143/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0342 - mean_absolute_error: 0.1374 - val_loss: 0.0373 - val_mean_absolute_error: 0.1465
# Epoch 144/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0338 - mean_absolute_error: 0.1364 - val_loss: 0.0368 - val_mean_absolute_error: 0.1455
# Epoch 145/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0333 - mean_absolute_error: 0.1354 - val_loss: 0.0362 - val_mean_absolute_error: 0.1445
# Epoch 146/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0329 - mean_absolute_error: 0.1344 - val_loss: 0.0357 - val_mean_absolute_error: 0.1435
# Epoch 147/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0325 - mean_absolute_error: 0.1335 - val_loss: 0.0352 - val_mean_absolute_error: 0.1425
# Epoch 148/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0321 - mean_absolute_error: 0.1325 - val_loss: 0.0347 - val_mean_absolute_error: 0.1415
# Epoch 149/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0316 - mean_absolute_error: 0.1316 - val_loss: 0.0341 - val_mean_absolute_error: 0.1405
# Epoch 150/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0312 - mean_absolute_error: 0.1307 - val_loss: 0.0337 - val_mean_absolute_error: 0.1396
# Epoch 151/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0308 - mean_absolute_error: 0.1298 - val_loss: 0.0332 - val_mean_absolute_error: 0.1386
# Epoch 152/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0305 - mean_absolute_error: 0.1290 - val_loss: 0.0327 - val_mean_absolute_error: 0.1377
# Epoch 153/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0301 - mean_absolute_error: 0.1281 - val_loss: 0.0322 - val_mean_absolute_error: 0.1367
# Epoch 154/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0297 - mean_absolute_error: 0.1272 - val_loss: 0.0318 - val_mean_absolute_error: 0.1359
# Epoch 155/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0293 - mean_absolute_error: 0.1263 - val_loss: 0.0313 - val_mean_absolute_error: 0.1350
# Epoch 156/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0290 - mean_absolute_error: 0.1255 - val_loss: 0.0309 - val_mean_absolute_error: 0.1341
# Epoch 157/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0286 - mean_absolute_error: 0.1247 - val_loss: 0.0305 - val_mean_absolute_error: 0.1333
# Epoch 158/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0283 - mean_absolute_error: 0.1240 - val_loss: 0.0301 - val_mean_absolute_error: 0.1325
# Epoch 159/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0280 - mean_absolute_error: 0.1233 - val_loss: 0.0296 - val_mean_absolute_error: 0.1317
# Epoch 160/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0276 - mean_absolute_error: 0.1226 - val_loss: 0.0292 - val_mean_absolute_error: 0.1309
# Epoch 161/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0273 - mean_absolute_error: 0.1220 - val_loss: 0.0289 - val_mean_absolute_error: 0.1302
# Epoch 162/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0270 - mean_absolute_error: 0.1213 - val_loss: 0.0285 - val_mean_absolute_error: 0.1294
# Epoch 163/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0267 - mean_absolute_error: 0.1207 - val_loss: 0.0281 - val_mean_absolute_error: 0.1286
# Epoch 164/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0265 - mean_absolute_error: 0.1201 - val_loss: 0.0277 - val_mean_absolute_error: 0.1279
# Epoch 165/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0262 - mean_absolute_error: 0.1195 - val_loss: 0.0274 - val_mean_absolute_error: 0.1272
# Epoch 166/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0259 - mean_absolute_error: 0.1189 - val_loss: 0.0270 - val_mean_absolute_error: 0.1265
# Epoch 167/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0256 - mean_absolute_error: 0.1183 - val_loss: 0.0267 - val_mean_absolute_error: 0.1258
# Epoch 168/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0253 - mean_absolute_error: 0.1177 - val_loss: 0.0264 - val_mean_absolute_error: 0.1252
# Epoch 169/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0251 - mean_absolute_error: 0.1171 - val_loss: 0.0260 - val_mean_absolute_error: 0.1245
# Epoch 170/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0248 - mean_absolute_error: 0.1166 - val_loss: 0.0257 - val_mean_absolute_error: 0.1238
# Epoch 171/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0246 - mean_absolute_error: 0.1161 - val_loss: 0.0254 - val_mean_absolute_error: 0.1232
# Epoch 172/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0243 - mean_absolute_error: 0.1156 - val_loss: 0.0251 - val_mean_absolute_error: 0.1226
# Epoch 173/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0241 - mean_absolute_error: 0.1151 - val_loss: 0.0248 - val_mean_absolute_error: 0.1220
# Epoch 174/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0238 - mean_absolute_error: 0.1146 - val_loss: 0.0245 - val_mean_absolute_error: 0.1214
# Epoch 175/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0236 - mean_absolute_error: 0.1142 - val_loss: 0.0242 - val_mean_absolute_error: 0.1209
# Epoch 176/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0234 - mean_absolute_error: 0.1137 - val_loss: 0.0239 - val_mean_absolute_error: 0.1203
# Epoch 177/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0232 - mean_absolute_error: 0.1133 - val_loss: 0.0237 - val_mean_absolute_error: 0.1197
# Epoch 178/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0229 - mean_absolute_error: 0.1128 - val_loss: 0.0234 - val_mean_absolute_error: 0.1191
# Epoch 179/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0227 - mean_absolute_error: 0.1123 - val_loss: 0.0231 - val_mean_absolute_error: 0.1185
# Epoch 180/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0225 - mean_absolute_error: 0.1119 - val_loss: 0.0228 - val_mean_absolute_error: 0.1179
# Epoch 181/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0223 - mean_absolute_error: 0.1115 - val_loss: 0.0226 - val_mean_absolute_error: 0.1174
# Epoch 182/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0221 - mean_absolute_error: 0.1110 - val_loss: 0.0223 - val_mean_absolute_error: 0.1168
# Epoch 183/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0219 - mean_absolute_error: 0.1106 - val_loss: 0.0220 - val_mean_absolute_error: 0.1162
# Epoch 184/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0217 - mean_absolute_error: 0.1102 - val_loss: 0.0218 - val_mean_absolute_error: 0.1157
# Epoch 185/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - mean_absolute_error: 0.1098 - val_loss: 0.0216 - val_mean_absolute_error: 0.1151
# Epoch 186/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0213 - mean_absolute_error: 0.1094 - val_loss: 0.0213 - val_mean_absolute_error: 0.1146
# Epoch 187/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0211 - mean_absolute_error: 0.1090 - val_loss: 0.0211 - val_mean_absolute_error: 0.1140
# Epoch 188/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0209 - mean_absolute_error: 0.1086 - val_loss: 0.0209 - val_mean_absolute_error: 0.1135
# Epoch 189/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0208 - mean_absolute_error: 0.1082 - val_loss: 0.0206 - val_mean_absolute_error: 0.1130
# Epoch 190/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0206 - mean_absolute_error: 0.1078 - val_loss: 0.0204 - val_mean_absolute_error: 0.1125
# Epoch 191/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0204 - mean_absolute_error: 0.1074 - val_loss: 0.0202 - val_mean_absolute_error: 0.1120
# Epoch 192/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0202 - mean_absolute_error: 0.1070 - val_loss: 0.0200 - val_mean_absolute_error: 0.1116
# Epoch 193/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0201 - mean_absolute_error: 0.1067 - val_loss: 0.0199 - val_mean_absolute_error: 0.1111
# Epoch 194/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0199 - mean_absolute_error: 0.1063 - val_loss: 0.0197 - val_mean_absolute_error: 0.1107
# Epoch 195/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0197 - mean_absolute_error: 0.1060 - val_loss: 0.0195 - val_mean_absolute_error: 0.1103
# Epoch 196/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0196 - mean_absolute_error: 0.1057 - val_loss: 0.0193 - val_mean_absolute_error: 0.1099
# Epoch 197/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0194 - mean_absolute_error: 0.1053 - val_loss: 0.0191 - val_mean_absolute_error: 0.1095
# Epoch 198/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0193 - mean_absolute_error: 0.1050 - val_loss: 0.0190 - val_mean_absolute_error: 0.1091
# Epoch 199/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0191 - mean_absolute_error: 0.1048 - val_loss: 0.0188 - val_mean_absolute_error: 0.1087
# Epoch 200/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - mean_absolute_error: 0.1044 - val_loss: 0.0186 - val_mean_absolute_error: 0.1083
# Epoch 201/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0188 - mean_absolute_error: 0.1042 - val_loss: 0.0185 - val_mean_absolute_error: 0.1079
# Epoch 202/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0187 - mean_absolute_error: 0.1039 - val_loss: 0.0183 - val_mean_absolute_error: 0.1075
# Epoch 203/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0185 - mean_absolute_error: 0.1036 - val_loss: 0.0182 - val_mean_absolute_error: 0.1071
# Epoch 204/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0184 - mean_absolute_error: 0.1033 - val_loss: 0.0180 - val_mean_absolute_error: 0.1067
# Epoch 205/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0183 - mean_absolute_error: 0.1030 - val_loss: 0.0178 - val_mean_absolute_error: 0.1063
# Epoch 206/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0181 - mean_absolute_error: 0.1027 - val_loss: 0.0177 - val_mean_absolute_error: 0.1059
# Epoch 207/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0180 - mean_absolute_error: 0.1024 - val_loss: 0.0176 - val_mean_absolute_error: 0.1055
# Epoch 208/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0179 - mean_absolute_error: 0.1021 - val_loss: 0.0174 - val_mean_absolute_error: 0.1052
# Epoch 209/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0177 - mean_absolute_error: 0.1019 - val_loss: 0.0173 - val_mean_absolute_error: 0.1048
# Epoch 210/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0176 - mean_absolute_error: 0.1016 - val_loss: 0.0171 - val_mean_absolute_error: 0.1044
# Epoch 211/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0175 - mean_absolute_error: 0.1014 - val_loss: 0.0170 - val_mean_absolute_error: 0.1041
# Epoch 212/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0174 - mean_absolute_error: 0.1011 - val_loss: 0.0169 - val_mean_absolute_error: 0.1038
# Epoch 213/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0173 - mean_absolute_error: 0.1009 - val_loss: 0.0167 - val_mean_absolute_error: 0.1034
# Epoch 214/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0172 - mean_absolute_error: 0.1007 - val_loss: 0.0166 - val_mean_absolute_error: 0.1031
# Epoch 215/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0171 - mean_absolute_error: 0.1005 - val_loss: 0.0165 - val_mean_absolute_error: 0.1027
# Epoch 216/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - mean_absolute_error: 0.1003 - val_loss: 0.0163 - val_mean_absolute_error: 0.1024
# Epoch 217/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0169 - mean_absolute_error: 0.1000 - val_loss: 0.0162 - val_mean_absolute_error: 0.1020
# Epoch 218/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0168 - mean_absolute_error: 0.0998 - val_loss: 0.0161 - val_mean_absolute_error: 0.1017
# Epoch 219/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0167 - mean_absolute_error: 0.0996 - val_loss: 0.0160 - val_mean_absolute_error: 0.1014
# Epoch 220/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0166 - mean_absolute_error: 0.0994 - val_loss: 0.0159 - val_mean_absolute_error: 0.1011
# Epoch 221/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0165 - mean_absolute_error: 0.0992 - val_loss: 0.0158 - val_mean_absolute_error: 0.1007
# Epoch 222/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0164 - mean_absolute_error: 0.0990 - val_loss: 0.0157 - val_mean_absolute_error: 0.1005
# Epoch 223/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0163 - mean_absolute_error: 0.0987 - val_loss: 0.0156 - val_mean_absolute_error: 0.1001
# Epoch 224/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0162 - mean_absolute_error: 0.0985 - val_loss: 0.0155 - val_mean_absolute_error: 0.0998
# Epoch 225/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0161 - mean_absolute_error: 0.0983 - val_loss: 0.0154 - val_mean_absolute_error: 0.0995
# Epoch 226/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0160 - mean_absolute_error: 0.0981 - val_loss: 0.0153 - val_mean_absolute_error: 0.0991
# Epoch 227/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0159 - mean_absolute_error: 0.0979 - val_loss: 0.0152 - val_mean_absolute_error: 0.0988
# Epoch 228/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0158 - mean_absolute_error: 0.0977 - val_loss: 0.0151 - val_mean_absolute_error: 0.0985
# Epoch 229/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0157 - mean_absolute_error: 0.0975 - val_loss: 0.0150 - val_mean_absolute_error: 0.0982
# Epoch 230/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0156 - mean_absolute_error: 0.0973 - val_loss: 0.0149 - val_mean_absolute_error: 0.0979
# Epoch 231/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0156 - mean_absolute_error: 0.0971 - val_loss: 0.0148 - val_mean_absolute_error: 0.0976
# Epoch 232/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0155 - mean_absolute_error: 0.0969 - val_loss: 0.0147 - val_mean_absolute_error: 0.0973
# Epoch 233/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0154 - mean_absolute_error: 0.0967 - val_loss: 0.0146 - val_mean_absolute_error: 0.0970
# Epoch 234/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0153 - mean_absolute_error: 0.0966 - val_loss: 0.0145 - val_mean_absolute_error: 0.0968
# Epoch 235/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0152 - mean_absolute_error: 0.0964 - val_loss: 0.0144 - val_mean_absolute_error: 0.0965
# Epoch 236/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0151 - mean_absolute_error: 0.0962 - val_loss: 0.0144 - val_mean_absolute_error: 0.0963
# Epoch 237/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0151 - mean_absolute_error: 0.0960 - val_loss: 0.0143 - val_mean_absolute_error: 0.0960
# Epoch 238/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0150 - mean_absolute_error: 0.0958 - val_loss: 0.0142 - val_mean_absolute_error: 0.0957
# Epoch 239/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0149 - mean_absolute_error: 0.0956 - val_loss: 0.0141 - val_mean_absolute_error: 0.0954
# Epoch 240/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0148 - mean_absolute_error: 0.0955 - val_loss: 0.0141 - val_mean_absolute_error: 0.0951
# Epoch 241/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0148 - mean_absolute_error: 0.0953 - val_loss: 0.0140 - val_mean_absolute_error: 0.0949
# Epoch 242/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0147 - mean_absolute_error: 0.0952 - val_loss: 0.0139 - val_mean_absolute_error: 0.0946
# Epoch 243/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0146 - mean_absolute_error: 0.0950 - val_loss: 0.0139 - val_mean_absolute_error: 0.0944
# Epoch 244/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0146 - mean_absolute_error: 0.0949 - val_loss: 0.0138 - val_mean_absolute_error: 0.0941
# Epoch 245/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0145 - mean_absolute_error: 0.0947 - val_loss: 0.0137 - val_mean_absolute_error: 0.0938
# Epoch 246/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0144 - mean_absolute_error: 0.0946 - val_loss: 0.0137 - val_mean_absolute_error: 0.0936
# Epoch 247/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0144 - mean_absolute_error: 0.0945 - val_loss: 0.0136 - val_mean_absolute_error: 0.0934
# Epoch 248/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0143 - mean_absolute_error: 0.0943 - val_loss: 0.0135 - val_mean_absolute_error: 0.0931
# Epoch 249/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0143 - mean_absolute_error: 0.0942 - val_loss: 0.0134 - val_mean_absolute_error: 0.0929
# Epoch 250/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0142 - mean_absolute_error: 0.0941 - val_loss: 0.0134 - val_mean_absolute_error: 0.0927
# Epoch 251/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0142 - mean_absolute_error: 0.0940 - val_loss: 0.0133 - val_mean_absolute_error: 0.0924
# Epoch 252/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0141 - mean_absolute_error: 0.0939 - val_loss: 0.0133 - val_mean_absolute_error: 0.0922
# Epoch 253/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0140 - mean_absolute_error: 0.0937 - val_loss: 0.0132 - val_mean_absolute_error: 0.0920
# Epoch 254/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0140 - mean_absolute_error: 0.0937 - val_loss: 0.0131 - val_mean_absolute_error: 0.0918
# Epoch 255/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0139 - mean_absolute_error: 0.0935 - val_loss: 0.0131 - val_mean_absolute_error: 0.0916
# Epoch 256/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0139 - mean_absolute_error: 0.0934 - val_loss: 0.0131 - val_mean_absolute_error: 0.0915
# Epoch 257/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0138 - mean_absolute_error: 0.0933 - val_loss: 0.0130 - val_mean_absolute_error: 0.0913
# Epoch 258/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0138 - mean_absolute_error: 0.0932 - val_loss: 0.0129 - val_mean_absolute_error: 0.0911
# Epoch 259/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0138 - mean_absolute_error: 0.0931 - val_loss: 0.0129 - val_mean_absolute_error: 0.0909
# Epoch 260/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0137 - mean_absolute_error: 0.0930 - val_loss: 0.0129 - val_mean_absolute_error: 0.0907
# Epoch 261/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - mean_absolute_error: 0.0929 - val_loss: 0.0128 - val_mean_absolute_error: 0.0905
# Epoch 262/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0136 - mean_absolute_error: 0.0928 - val_loss: 0.0128 - val_mean_absolute_error: 0.0904
# Epoch 263/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0136 - mean_absolute_error: 0.0927 - val_loss: 0.0127 - val_mean_absolute_error: 0.0902
# Epoch 264/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - mean_absolute_error: 0.0926 - val_loss: 0.0127 - val_mean_absolute_error: 0.0900
# Epoch 265/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0135 - mean_absolute_error: 0.0925 - val_loss: 0.0126 - val_mean_absolute_error: 0.0898
# Epoch 266/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0135 - mean_absolute_error: 0.0924 - val_loss: 0.0126 - val_mean_absolute_error: 0.0897
# Epoch 267/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mean_absolute_error: 0.0923 - val_loss: 0.0125 - val_mean_absolute_error: 0.0896
# Epoch 268/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0134 - mean_absolute_error: 0.0922 - val_loss: 0.0125 - val_mean_absolute_error: 0.0894
# Epoch 269/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0133 - mean_absolute_error: 0.0921 - val_loss: 0.0125 - val_mean_absolute_error: 0.0893
# Epoch 270/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0133 - mean_absolute_error: 0.0920 - val_loss: 0.0124 - val_mean_absolute_error: 0.0891
# Epoch 271/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0133 - mean_absolute_error: 0.0919 - val_loss: 0.0124 - val_mean_absolute_error: 0.0890
# Epoch 272/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0132 - mean_absolute_error: 0.0918 - val_loss: 0.0124 - val_mean_absolute_error: 0.0889
# Epoch 273/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0132 - mean_absolute_error: 0.0918 - val_loss: 0.0123 - val_mean_absolute_error: 0.0888
# Epoch 274/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - mean_absolute_error: 0.0917 - val_loss: 0.0123 - val_mean_absolute_error: 0.0886
# Epoch 275/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mean_absolute_error: 0.0916 - val_loss: 0.0123 - val_mean_absolute_error: 0.0885
# Epoch 276/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0131 - mean_absolute_error: 0.0915 - val_loss: 0.0123 - val_mean_absolute_error: 0.0884
# Epoch 277/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0131 - mean_absolute_error: 0.0914 - val_loss: 0.0122 - val_mean_absolute_error: 0.0883
# Epoch 278/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mean_absolute_error: 0.0913 - val_loss: 0.0122 - val_mean_absolute_error: 0.0882
# Epoch 279/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0130 - mean_absolute_error: 0.0913 - val_loss: 0.0122 - val_mean_absolute_error: 0.0880
# Epoch 280/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0130 - mean_absolute_error: 0.0912 - val_loss: 0.0121 - val_mean_absolute_error: 0.0880
# Epoch 281/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0130 - mean_absolute_error: 0.0911 - val_loss: 0.0121 - val_mean_absolute_error: 0.0878
# Epoch 282/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129 - mean_absolute_error: 0.0910 - val_loss: 0.0121 - val_mean_absolute_error: 0.0877
# Epoch 283/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0129 - mean_absolute_error: 0.0910 - val_loss: 0.0121 - val_mean_absolute_error: 0.0876
# Epoch 284/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0129 - mean_absolute_error: 0.0909 - val_loss: 0.0120 - val_mean_absolute_error: 0.0875
# Epoch 285/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0129 - mean_absolute_error: 0.0908 - val_loss: 0.0120 - val_mean_absolute_error: 0.0874
# Epoch 286/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0128 - mean_absolute_error: 0.0907 - val_loss: 0.0120 - val_mean_absolute_error: 0.0873
# Epoch 287/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0128 - mean_absolute_error: 0.0907 - val_loss: 0.0120 - val_mean_absolute_error: 0.0872
# Epoch 288/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0128 - mean_absolute_error: 0.0906 - val_loss: 0.0119 - val_mean_absolute_error: 0.0871
# Epoch 289/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - mean_absolute_error: 0.0905 - val_loss: 0.0119 - val_mean_absolute_error: 0.0870
# Epoch 290/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0905 - val_loss: 0.0119 - val_mean_absolute_error: 0.0870
# Epoch 291/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0127 - mean_absolute_error: 0.0904 - val_loss: 0.0119 - val_mean_absolute_error: 0.0868
# Epoch 292/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0127 - mean_absolute_error: 0.0903 - val_loss: 0.0118 - val_mean_absolute_error: 0.0868
# Epoch 293/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0127 - mean_absolute_error: 0.0903 - val_loss: 0.0118 - val_mean_absolute_error: 0.0867
# Epoch 294/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0126 - mean_absolute_error: 0.0902 - val_loss: 0.0118 - val_mean_absolute_error: 0.0866
# Epoch 295/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0126 - mean_absolute_error: 0.0901 - val_loss: 0.0118 - val_mean_absolute_error: 0.0865
# Epoch 296/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0126 - mean_absolute_error: 0.0901 - val_loss: 0.0117 - val_mean_absolute_error: 0.0864
# Epoch 297/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0126 - mean_absolute_error: 0.0900 - val_loss: 0.0117 - val_mean_absolute_error: 0.0864
# Epoch 298/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0126 - mean_absolute_error: 0.0899 - val_loss: 0.0117 - val_mean_absolute_error: 0.0863
# Epoch 299/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0125 - mean_absolute_error: 0.0899 - val_loss: 0.0117 - val_mean_absolute_error: 0.0862
# Epoch 300/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125 - mean_absolute_error: 0.0898 - val_loss: 0.0117 - val_mean_absolute_error: 0.0862
# Epoch 301/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0125 - mean_absolute_error: 0.0898 - val_loss: 0.0116 - val_mean_absolute_error: 0.0861
# Epoch 302/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0125 - mean_absolute_error: 0.0897 - val_loss: 0.0116 - val_mean_absolute_error: 0.0861
# Epoch 303/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125 - mean_absolute_error: 0.0897 - val_loss: 0.0116 - val_mean_absolute_error: 0.0860
# Epoch 304/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0124 - mean_absolute_error: 0.0896 - val_loss: 0.0116 - val_mean_absolute_error: 0.0859
# Epoch 305/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - mean_absolute_error: 0.0896 - val_loss: 0.0116 - val_mean_absolute_error: 0.0859
# Epoch 306/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0124 - mean_absolute_error: 0.0895 - val_loss: 0.0115 - val_mean_absolute_error: 0.0858
# Epoch 307/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0124 - mean_absolute_error: 0.0895 - val_loss: 0.0115 - val_mean_absolute_error: 0.0858
# Epoch 308/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0124 - mean_absolute_error: 0.0894 - val_loss: 0.0115 - val_mean_absolute_error: 0.0857
# Epoch 309/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0124 - mean_absolute_error: 0.0894 - val_loss: 0.0115 - val_mean_absolute_error: 0.0857
# Epoch 310/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0124 - mean_absolute_error: 0.0893 - val_loss: 0.0115 - val_mean_absolute_error: 0.0856
# Epoch 311/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0123 - mean_absolute_error: 0.0893 - val_loss: 0.0115 - val_mean_absolute_error: 0.0856
# Epoch 312/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0123 - mean_absolute_error: 0.0893 - val_loss: 0.0114 - val_mean_absolute_error: 0.0855
# Epoch 313/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0123 - mean_absolute_error: 0.0892 - val_loss: 0.0114 - val_mean_absolute_error: 0.0855
# Epoch 314/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0123 - mean_absolute_error: 0.0892 - val_loss: 0.0114 - val_mean_absolute_error: 0.0854
# Epoch 315/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0123 - mean_absolute_error: 0.0891 - val_loss: 0.0114 - val_mean_absolute_error: 0.0854
# Epoch 316/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0123 - mean_absolute_error: 0.0891 - val_loss: 0.0114 - val_mean_absolute_error: 0.0853
# Epoch 317/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0123 - mean_absolute_error: 0.0891 - val_loss: 0.0114 - val_mean_absolute_error: 0.0853
# Epoch 318/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - mean_absolute_error: 0.0890 - val_loss: 0.0113 - val_mean_absolute_error: 0.0853
# Epoch 319/500
# ...
# Epoch 396/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0875 - val_loss: 0.0109 - val_mean_absolute_error: 0.0840
# Epoch 397/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0875 - val_loss: 0.0109 - val_mean_absolute_error: 0.0840
# Epoch 398/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0875 - val_loss: 0.0109 - val_mean_absolute_error: 0.0840
# Epoch 399/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0875 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 400/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - mean_absolute_error: 0.0875 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 401/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0875 - val_loss: 0.0109 - val_mean_absolute_error: 0.0840
# Epoch 402/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - mean_absolute_error: 0.0875 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 403/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0875 - val_loss: 0.0109 - val_mean_absolute_error: 0.0840
# Epoch 404/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0875 - val_loss: 0.0109 - val_mean_absolute_error: 0.0840
# Epoch 405/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0874 - val_loss: 0.0109 - val_mean_absolute_error: 0.0840
# Epoch 406/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0874 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 407/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0874 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 408/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0874 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 409/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - mean_absolute_error: 0.0874 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 410/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0874 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 411/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0874 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 412/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0874 - val_loss: 0.0109 - val_mean_absolute_error: 0.0840
# Epoch 413/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0874 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 414/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0874 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 415/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0118 - mean_absolute_error: 0.0874 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 416/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0873 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 417/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0873 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 418/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0118 - mean_absolute_error: 0.0873 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 419/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0118 - mean_absolute_error: 0.0873 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 420/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0873 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 421/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0873 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 422/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0873 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 423/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0873 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 424/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0873 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 425/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0118 - mean_absolute_error: 0.0873 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 426/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 427/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0109 - val_mean_absolute_error: 0.0839
# Epoch 428/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 429/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 430/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 431/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 432/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 433/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 434/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 435/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 436/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 437/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 438/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 439/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 440/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 441/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 442/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 443/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 444/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0872 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 445/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 446/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 447/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 448/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 449/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 450/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 451/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 452/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 453/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 454/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 455/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 456/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 457/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 458/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 459/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 460/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 461/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 462/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 463/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 464/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 465/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0839
# Epoch 466/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 467/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 468/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 469/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 470/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 471/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 472/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 473/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 474/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 475/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 476/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 477/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 478/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 479/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 480/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 481/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 482/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 483/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 484/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 485/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 486/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mean_absolute_error: 0.0871 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 487/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 488/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 489/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 490/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 491/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 492/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 493/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 494/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 495/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 496/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 497/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 498/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 499/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 500/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mean_absolute_error: 0.0870 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840

# %% [markdown]
# ## Plotting Loss Curves
#
# The following code plots the loss curves (Training loss and validation loss) with each epoch. The loss curve can be used to check whether your model converged correctly.
#
# <img src="https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/images/04-loss-curves-overfitting-underfitting-ideal.jpg" alt="Loss Curves" width="600"/>
#
# Run the below cell and make sure your loss curves appear to be as the ones on the right of the below image. For more reading, refer to [this](https://www.learnpytorch.io/04_pytorch_custom_datasets/#8-what-should-an-ideal-loss-curve-look-like).

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

# Exclude the first few epochs so the graph is easier to read
SKIP = 100

plt.plot(epochs[SKIP:], loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.clf()

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
mae = history.history['mean_absolute_error']
val_mae = history.history['val_mean_absolute_error']

plt.plot(epochs[SKIP:], mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %% [markdown]
# ## Predict using model (Graded)
#
# Use `model.predict()` to predict values for all data in test set and plot it against true values. You may refer to this [documentation](https://www.tensorflow.org/guide/keras/training_with_built_in_methods) for more information.
#
# ### Exercise 5
# Predict y values for test data and plot it with true values.

# %%
# Make predictions based on our test dataset (TODO)
predictions = model.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Predicted')
plt.legend()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %% [markdown]
# ### Exercise 6
# The predicted graph is not nearly as smooth enough to be a sine. Rather it may look like a piecewise combination of linear functions. Briefly explain how you can make this more smoother and identical to an actual sine wave.
#
# Answer:
#
# 1)Increase model complexity by adding more hidden layers and/or units.
#
# 2)Use different activation functions like tanh or sigmoid for smoother activations.
#
# 3)Use Regularization techniques(like L2 regularization or dropout) to help avoid overfitting by encouraging the model to generalize better, which can lead to smoother predictions.
#
# 4)Increase dataset size.

# %% [markdown]
# ## Get weights
#
# Now you will extract the weight matrices from the model. This step is in order to convert these weight matrices to C++ files that will be embedded in the Microcontroller.

# %%
# Extract weights and biases as Numpy arrays
W1, b1 = model.layers[0].get_weights()
W2, b2 = model.layers[1].get_weights()
W3, b3 = model.layers[2].get_weights()

# %%
print(W1.shape, b1.shape)
print(W2.shape, b2.shape)
print(W3.shape, b3.shape)
# Out:
# (1, 16) (16,)
# (16, 16) (16,)
# (16, 1) (1,)

# %% [markdown]
# The following code performs the forward propagation of the model manually using NumPy matrix multiplication. Run the following code to make sure the model's prediction and manual prediction is same.

# %%
xs = x_test

# %%
# This is what the TF model does internally:
ys = []
for x in xs:
    x = np.array([x])       # x should be array
    h1 = x @ W1 + b1        # dense layer
    h1 = np.maximum(0, h1)  # ReLU
    h2 = h1 @ W2 + b2       # dense layer
    h2 = np.maximum(0, h2)  # ReLU
    h3 = h2 @ W3 + b3       # dense layer
    ys.append(h3)

ys = np.stack(ys)

# %%
# Are our predictions the same as TF's predictions?
# This should print 0 if the results are close enough.
np.sum(np.abs(ys - predictions) > 1e-6)
# Out:
# 0

# %% [markdown]
# ## Export the weights for C++
#
# The following code compresses the weights and biases into a C++ format which will be stored in the Microcontroller's FLASH memory. Copy the generated output and paste in file named `model_data.cpp`.

# %%
# Note that we transpose W2. This makes the inner loop for the
# matrix multiplication a little simpler.

names = ["W1_data", "b1_data", "W2_data", "b2_data", "W3_data", "b3_data"]
arrays = [W1, b1, W2.T, b2, W3, b3]

# %%
# Copy this into model_data.cpp:

for name, array in zip(names, arrays):
    print("const float %s[] PROGMEM = {" % name)
    print("   ", ", ".join([str(x) + "f" for x in array.flatten()]))
    print("};\n")
# Out:
# const float W1_data[] PROGMEM = {
#     0.18522173f, -0.11512017f, -0.5008662f, -0.033245742f, 0.061070003f, -0.15960887f, -0.12890378f, 0.35374984f, 0.36631018f, -0.53511316f, 0.3407005f, 0.34590802f, -0.53515625f, -0.58705777f, 0.22012518f, -0.044813633f
# };
#
# const float b1_data[] PROGMEM = {
#     -0.46117643f, 0.0f, 0.0f, 0.0f, 0.3436834f, 0.0f, 0.0f, -0.67787623f, 0.3627041f, 0.0f, 0.25442022f, -0.5490121f, 0.0f, 0.0f, -0.37951922f, 0.0f
# };
#
# const float W2_data[] PROGMEM = {
#     -0.8022953f, 0.30509833f, -0.13495585f, -0.42926028f, 0.07928f, -0.38567f, 0.04720685f, -0.58268374f, 0.2110064f, 0.01290828f, 0.110498495f, -0.40280965f, 0.06203711f, -0.3030638f, 0.16153415f, 0.17181036f, -0.09581998f, -0.28701758f, 0.014815509f, 0.3808811f, -0.4061253f, -0.22481373f, 0.2039878f, 0.20557651f, 0.04362592f, 0.17893413f, -0.32201874f, -0.1939782f, -0.29593903f, 0.3102266f, -0.40373152f, 0.22390059f, 0.2984569f, -0.08390319f, 0.14945105f, -0.10143471f, 0.11150087f, -0.24161111f, -0.30812123f, 0.38408732f, -0.21616656f, -0.30921918f, 0.49201712f, 0.44132942f, -0.42797467f, 0.2831742f, -0.24331254f, 0.27742395f, -0.36870712f, 0.27844158f, -0.17070323f, -0.350302f, 0.6029379f, -0.23354748f, 0.41479042f, -0.19053206f, -0.8585953f, 0.3039573f, -0.65716577f, -0.03964769f, -0.25805026f, -0.365712f, -0.9476904f, 0.2931681f, -0.28722212f, -0.15915006f, -0.14382556f, -0.14601278f, 0.043047756f, -0.20295106f, -0.12051663f, -0.27854317f, -0.19933987f, 0.36737803f, 0.48045564f, -0.3453289f, -0.14336792f, 0.3398929f, -0.2620878f, 0.29726365f, -0.14192733f, -0.018848628f, -0.09625617f, -0.402838f, -0.2824123f, -0.34117338f, 0.08965853f, 0.24221864f, 0.087201215f, 0.18034819f, 0.4049518f, 0.4403145f, 0.1538566f, 0.40049472f, -0.08732052f, 0.35420135f, 0.31951252f, 0.08587989f, 0.3612592f, -0.3265664f, -0.38346514f, 0.20652887f, -0.30990973f, 0.2720302f, 0.38704237f, 0.41831467f, 0.3501876f, -0.07299449f, -0.3106526f, -0.040480763f, 0.1349334f, 0.25408778f, -0.015390973f, -0.30046445f, 0.28237483f, 0.1636112f, 0.11321034f, -0.030468911f, 0.15166506f, -0.122932404f, 0.33820847f, 0.1478217f, -0.4340036f, 0.42279285f, 0.19403884f, 0.25061896f, 0.26421553f, -0.067509145f, -0.245953f, 0.27960762f, -0.14246202f, -0.42329085f, -0.42371958f, 0.42021403f, -0.23842642f, 0.11683217f, 0.04125762f, 0.10330209f, -0.16078392f, 0.08323935f, -0.057143718f, -0.32836935f, 0.14513555f, 0.123696715f, -1.0640097f, -0.07608184f, 0.034095168f, -0.1319924f, 0.41721818f, 0.30340436f, 0.071833104f, -0.86102325f, 0.4653526f, 0.40960476f, 0.21970476f, -0.56188226f, 0.37448576f, 0.23004457f, -0.07381156f, -0.0016654432f, 0.39776242f, -0.40257382f, -0.23952982f, -0.15480557f, -0.25016135f, 0.21913573f, -0.21587484f, 0.7735313f, -0.41292277f, 0.061336637f, -0.046122894f, 0.518317f, -0.27954942f, 0.11694059f, 0.510506f, -0.20688444f, 0.22654676f, -0.07656357f, 0.35338637f, 0.005990386f, -0.40131134f, 0.13833794f, -0.02100733f, -0.018059477f, 0.045640945f, 0.23681721f, -0.27964988f, 0.38783756f, 0.38171646f, -0.16566512f, -0.07319926f, -0.31806237f, -0.021297634f, 0.32584158f, 0.059603184f, -0.19189703f, -0.23980558f, -0.19146684f, -0.3898943f, -0.3214943f, 0.32407072f, -0.3898881f, -0.41327032f, 0.098932415f, -0.23845935f, 0.3191636f, -0.09646729f, 0.32757667f, 0.26714864f, -0.10327202f, 0.14837417f, -0.26284805f, 0.07922338f, 0.34245095f, 0.3371422f, -0.106463134f, -0.3126794f, 0.22577819f, -0.27450192f, 0.14066836f, 0.320047f, -0.092274874f, 0.3315706f, 0.08550945f, -0.3323209f, 0.19845232f, 0.39950374f, -0.07847968f, -0.40850496f, 0.18455091f, -0.11278358f, 0.26891616f, 0.057733327f, -0.30376282f, -0.046260566f, -0.41539282f, -0.07025859f, -0.28093642f, -0.014163166f, 0.40287897f, -0.19362728f, 0.16960439f, 0.14559361f, 0.1672329f, 0.022750279f, -0.20227124f, 0.30750415f, 0.32824698f, -0.054338027f, -0.19313651f, 0.23614913f, 0.27872723f, -0.28429663f, 0.036752313f, 0.21417694f, 0.16348419f
# };
#
# const float b2_data[] PROGMEM = {
#     0.26410246f, 0.0f, 0.08674545f, 0.7692273f, 0.24303217f, 0.013991952f, -0.111223295f, -0.15946962f, 0.0f, 0.20587696f, -0.8103596f, -0.015813705f, 0.0f, -0.03838218f, 0.0f, -0.11127898f
# };
#
# const float W3_data[] PROGMEM = {
#     0.87517434f, -0.24966893f, -0.51620215f, -1.2704384f, 0.8289762f, -0.18218097f, -0.12736434f, 0.18202457f, -0.3395076f, 0.55053836f, 2.000163f, 0.44922847f, -0.2005674f, 0.08089662f, 0.09607375f, 0.2817935f
# };
#
# const float b3_data[] PROGMEM = {
#     -0.15618072f
# };

# %% [markdown]
# ## End of Section 1
