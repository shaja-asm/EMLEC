# %% [markdown]
# # Projection, Layernorm, Dropout
#
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/SkillSurf/introduction_genAI/blob/main/notebooks/S1/Session_1_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>
#
# <br />
# <br />

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import re

# %% [markdown]
# ### Hyperparameters

# %%
'''Hyperparameters for smaller model'''

# B = 32 # B: how many independent sequences will we process in parallel?
# T = 8  # T: what is the maximum context length for predictions?
# C = 32 # C: numer of different features analysed (also D = dims)
# H = 4  # H: number of attention heads
# L = 4  # L: Number of layers
# learning_rate = 1e-3

'''Final Hyperparameters'''

B = 64 # B: how many independent sequences will we process in parallel?
T = 256  # T: what is the maximum context length for predictions?
H = 6
C = 64*H
L = 6
learning_rate = 1e-4

# Common Hyperparameters
max_iters = 5000
eval_interval = 500
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
dropout = 0.2
torch.manual_seed(1337)

# %% [markdown]
# ### Data

# %%
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Out:
# --2024-07-15 08:33:32--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M  --.-KB/s    in 0.008s
#
# 2024-07-15 08:33:32 (132 MB/s) - ‘input.txt’ saved [1115394/1115394]

# %%
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
# chars = sorted(list(set(text)))
# vocab_size = len(chars)
# # create a mapping from characters to integers
# stoi = { ch:i for i,ch in enumerate(chars) }
# itos = { i:ch for i,ch in enumerate(chars) }
# encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
# decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# chars_str = ''.join(chars)
# print(f'vocab_size: {vocab_size}')
# print(f'vocabulary: {chars_str}')

words = re.split(r'\s+|\n|\n\n|,', text)
words = [word for word in words if word]

unique_words = sorted(set(words))
vocab_size = len(unique_words)

stoi = { word: i for i, word in enumerate(unique_words) }
itos = { i: word for i, word in enumerate(unique_words) }
encode = lambda s: [stoi[word] for word in re.split(r'\s+|\n|\n\n|,', s) if word] # Encoder: take a string, output a list of integers
decode = lambda l: ' '.join([itos[i] for i in l]) # Decoder: take a list of integers, output a string


unique_words_str = ', '.join(unique_words)
print(f'vocab_size: {vocab_size}')
print(f'vocabulary: {unique_words_str}')

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - T, (B,))
    x = torch.stack([data[i:i+T] for i in ix])
    y = torch.stack([data[i+1:i+T+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y
# Out:
# vocab_size: 22241
# vocabulary: &C:, &c., ', '--this, '?, 'A, 'Alas, 'Alla, 'An, 'Ay, 'Ay.', 'Be, 'Beseech, 'Bless, 'Bove, 'Brutus!', 'By, 'Charge, 'Charge!, 'Citizens!', 'Clarence, 'Come, 'Commend, 'Con, 'Content', 'Coriolanus!', 'Courage, 'Courage!', 'Cucullus, 'Dear, 'Death.', 'Deny, 'Do, 'Fair, 'Faith, 'Farewell:', 'Fine;', 'Fore, 'Forgive, 'Frets, 'G', 'Gainst, 'Go, 'God, 'Good, 'Have, 'He, 'Heart's, 'Hell, 'Hic, 'Hold, 'I, 'I', 'I';, 'I'll, 'I.', 'Is, 'It, 'Jack, 'Jesu, 'King, 'Lo, 'Madam, 'Margaret.', 'My, 'Now, 'O, 'Pardon', 'Patricians!', 'Peace, 'Priami, 'Proud, 'Redime, 'Remember, 'Retire, 'Rise;', 'Romeo, 'Saint, 'Save, 'Scape, 'Shall'!, 'She, 'Sicilia, 'Sicinius!', 'Sigeia, 'Signior, 'Simois, 'Sir, 'Sirrah, 'Small, 'Stay, 'Stay:, 'Tear, 'Tell, 'Thanks, 'That, 'The, 'Then, 'They, 'This, 'Thou, 'Though, 'Thus, 'Tis, 'Tribunes!', 'True, 'Twas, 'Twere, 'Twill, 'Twixt, 'Two, 'Twould, 'Tybalt, 'Tybalt's, 'Verily, 'Verily', 'Warwick, 'We, 'Welcome, 'What, 'When, 'Whoop, 'Why, 'Widow, 'Will't, 'Wilt, 'Wind-changing, 'Yea, 'Your, 'Zounds, 'Zounds!, 'aged, 'all, 'almost, 'ay', 'banished, 'banished', 'banished'?, 'banishment.', 'better:', 'bout, 'broad;', 'celsa, 'cerns, 'cum, 'death;', 'dost, 'dove;', 'em, 'em!, 'em., 'em:, 'em;, 'ever', 'fall'st, 'farewell', 'flayed, 'for, 'fore, 'gainst, 'girdling, 'good, 'good', 'grace.', 'greed, 'havior, 'head, 'her, 'hic, 'honour', 'if, 'ifs'?, 'judgment', 'jump, 'knocking, 'lady, 'larum, 'larums, 'lay, 'leges, 'leven, 'long, 'longeth, 'longs, 'lord:', 'lordship:', 'love, 'love', 'madam, 'man.', 'marry', 'mildly.', 'mong, 'mongst, 'music, 'my, 'never, 'no', 'no.', 'nointed, 'not, 'once', 'only', 'pardon, 'pardon', 'pardonne, 'point, 'pointed, 'pothecary, 'regia, 's, 's!, 's., 's:, 'scape, 'scape., 'scape:, 'scape;, 'scaped, 'scapes, 'shall, 'shall', 'shall'?, 'she, 'she's, 'shrew, 'silver, 'stand, 'stoned, 'supposed, 't, 't., 't:, 't;, 'the, 'thwack, 'tis, 'tis., 'tis;, 'twas, 'twere, 'twill, 'twixt, 'twould, 'unjust'!, 'voided, 'we, 'why?', 'widower, 'woe!', 'your, 'zounds!, --, --Ding-dong, --Hold, --I, --O, --Tybalt, --Where, --a, --an, --and, --as, --be, --believe, --but, --cast, --cousin, --do, --for, --give, --goddess!--O, --here, --if, --it, --let, --like, --mightst, --or, --part, --poor, --so, --that, --that's, --the, --then, --there, --there's, --thine, --this, --thou, --we, --what, --whate'er, --which, --whither, --whom, --will, --you, --your, 3, :, A, A', ABHORSON:, ABRAHAM:, ADRIAN:, AEacides, AEdile:, AEdiles, AEdiles!, AEneas', AEsop, ALL, ALL:, ALONSO:, ANGELO:, ANNE:, ANOTHER:, ANTIGONUS:, ANTONIO:, ARCHBISHOP, ARCHIDAMUS:, ARIEL:, AUFIDIUS:, AUMERLE:, AUTOLYCUS:, Abase, Abate, Abated, Abbot, Abbot:, Abel's, Abhorred, Abhorson, Abhorson!, Abhorson?, Abides, Able, About, Above, Abraham!, Abraham's, Absolute, Accept, Accomplish'd, According, Accords, Account, Accountant, Accursed, Accuse, Achieve, Acquaint, Action, Adam, Adam's, Add, Added, Adding, Address, Adieu, Adjudged, Admit, Adonis, Adoptedly;, Adopts, Adrian, Adrian., Adriatic, Advance, Advantaging, Adversity's, Advertising, Advocate's, Affection, Affection!, Affection's, Affliction, Affrighted, Affrights, Affront, Afore, Afresh, Afric, African;, After, Again, Against, Agamemnon's, Age, Aged, Agenor, Agreed., Agrippa;, Ah, Ah!, Ah., Aim'd, Aiming, Airy, Ajax, Al'ce, Alack, Alack!, Alack., Alas, Alas!, Alban's, Albeit, Albion, Albion's, Alcides', Alexander, Alexander., Alike, Alive, All, All's, All-Seer, All-Souls', All-hallond, All:, Alla, Allaying, Allot, Allow, Allowing, Almost, Alone, Alps, Already;, Although, Always, Am, Amazon., Amazonian, Ambitious, Amen, Amen!, Amen., Amity, Among, Amongst, An, An't, Anchors, Ancient, Ancus, And, Angelica:, Angelo, Angelo!, Angelo's, Angelo., Angelo:, Angelo:--, Angelo;, Angelo?, Anger's, Anna, Anne, Anne., Anointed, Anon, Anon!, Another, Another's, Anselme, Answer, Anthony, Antiates, Antiates;, Antigonus, Antipodes, Antium, Antium., Antium?, Antonio, Antonio's, Antonio--, Antony, Any, Apollo,  ...

# %% [markdown]
# ### Head, MHSA

# %%
class Head(nn.Module):
    """ One head of self attention"""

    def __init__(self, Ci, Co):
        super().__init__()
        self.key   = nn.Linear(Ci, Co, bias=False)
        self.query = nn.Linear(Ci, Co, bias=False)
        self.value = nn.Linear(Ci, Co, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(T, T)))

    def forward(self, x):
        B, T, Ci  = x.shape
        '''
        B  - batch               # of independant vectors processed
        T  - time/block/context  # of tokens in a context
        Ci - channals/dims input # of features in input
        '''

        k = self.key(x)   # (B,T,Co)
        q = self.query(x) # (B,T,Co)

        # compute attention scores / affinities
        wei = q @ k.transpose(-2,-1)                                 # (B,T,Co) @ (B,Co,T) -> (B,T,T)
        wei /= C**0.5                                                # (B,T,T) scaling, bring variance to 1, to prevent softmax clipping
        wei  = wei.masked_fill(self.tril[:T,:T]==0, float('-inf'))   # (B,T,T) Replace upper triangular of wei with -inf
        wei  = F.softmax(wei, dim=-1)                                # (B,T,T) -inf -> 0, rest normalized to 1

        v = self.value(x)  # (B,T,Co)
        out = wei @ v      # (B,T,T) @ (B,T,Co) = (B,T,Co)

        return out


class MultiHeadAttention(nn.Module):

    def __init__(self, Ci, H, head_size):
        super().__init__()
        # 4 heads of 8-dimensional self-attention, for n_embed=32, like a group convolution
        self.heads = nn.ModuleList([Head(Ci=Ci, Co=head_size) for _ in range(H)])

    def forward(self, x):
        x = torch.cat([h(x) for h in self.heads], dim=-1)
        return x

# %% [markdown]
# ### Transformer Block

# %%
class Block(nn.Module):
    ''' Transformer block: communication followed by computation '''

    def __init__(self, C, H): # C: embedding dimension, H: number of heads
        super().__init__()
        self.ln1 = nn.LayerNorm(C)   # Layernorm along channels (batch & time are batch dims): y = beta + gamma * [x-E(x)]/sqrt(V(x) + ep)
        self.sa = MultiHeadAttention(Ci=C, H=H, head_size=C//H)
        self.ln2 = nn.LayerNorm(C)
        self.ffwd = nn.Sequential(         # Feedforward network, so the tokens can "think about" what they found in attention.
            nn.Linear(C, C*4),
            nn.ReLU(),
            nn.Linear(C*4, C),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        # Residual connections around MSA & FF, to help training
        # Note: input without layernorm is added to output

        x_skip = x

        x = self.ln1(x)
        x = self.sa(x)   # (B,T,C), Multi head self attention
        x = x + x_skip

        x = self.ln2(x)
        x = self.ffwd(x) # (B,T,C), Per token level. B,T act as batch dimensions
        x = x + x_skip

        return x

# %% [markdown]
# ### Model

# %%
class BigramLanguageModel(nn.Module):

    def __init__(self, B,T,C,H,L):
        super().__init__()
        self.B, self.T, self.C, self.H, self.L = B,T,C,H,L
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, C) # for every possible token, weights for next token
        self.position_embedding_table = nn.Embedding(T, C)

        self.blocks  = nn.Sequential(*[Block(C, H) for _ in range(L)])
        self.ln_final = nn.LayerNorm(C)
        self.lm_head = nn.Linear(C, vocab_size)

    def forward(self, idx, targets=None):

        tok_emb = self.token_embedding_table(idx)                                    # (B,T,C=n_embed)
        pos_emb = self.position_embedding_table(torch.arange(self.T, device=device)) # (T,C): [0,1,2..T-1]

        x = tok_emb + pos_emb     # (B,T,C)
        x = self.blocks(x)
        x = self.ln_final(x)      # Layernorm applied before last
        logits = self.lm_head(x)  # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):                        # idx is (B, T) array of indices in the current context
            idx_cond = idx[:, -self.T:]                        # crop the last block_size tokens for input
            logits, loss = self(idx_cond)                      # get the predictions
            logits = logits[:, -1, :]                          # (B,T,C) -> (B, C)
            probs = F.softmax(logits, dim=-1)                  # (B, C)
            idx_next = torch.multinomial(probs, num_samples=1) # sample from the distribution acc to prob (B, 1)
            idx = torch.cat((idx, idx_next), dim=1)            # New idx is concat (B, T+1)
        return idx

model = BigramLanguageModel(B,T,C,H,L)
m = model.to(device)

# %% [markdown]
# ### Training

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):
    if iter % eval_interval == 0:   # every once in a while evaluate the loss on train and val sets
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    xb, yb = get_batch('train')     # sample a batch of data

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 10.1735, val loss 10.1687
# step 500: train loss 6.2718, val loss 7.2227
# step 1000: train loss 5.3280, val loss 7.2144
# step 1500: train loss 4.5601, val loss 7.4034
# step 2000: train loss 3.8798, val loss 7.6983
# step 2500: train loss 3.1676, val loss 8.0421
# step 3000: train loss 2.4890, val loss 8.4490
# step 3500: train loss 1.8696, val loss 8.9193
# step 4000: train loss 1.3583, val loss 9.3472
# step 4500: train loss 0.9658, val loss 9.8074

# %% [markdown]
# ### Inference

# %%
context = torch.ones((1, T), dtype=torch.long, device=device)  # start with '\n\n\n\n' as seed
out_ints = m.generate(context, max_new_tokens=2000)[0].tolist() # output list of ints
print(decode(out_ints))
# Out:
# &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. &c. MONTAGUE: An honour! thou and his downfall? thee his clouds with his law. PRINCE: Fear madst days; And long did fight grown thou a king at blood was found true knight in the rest was Corioli like a story ready when of a golden days: But 'tis all the world's thraldom of a current blood he of heaven: Where be seen a shower how made a man to God in his happy and himself means to God in fair peace men what is predominant For how he is there lad bear the heaven King Edward is there ere now may fall To those enemies The storm begins; poor man! Or by whose all That ne'er know his good hath and tide. NORTHUMBERLAND: These both have we have his head. WARWICK: Injurious Margaret! KING HENRY rough unswayable hath our account. Lieutenant: He slain His Exceeds in the time of Gloucester and always loved the traitor to our law DUKE VINCENTIO: Be executed him? DUKE VINCENTIO: Hold your hand; When time shall proceed He must he live off the marshal hence the name of the ground. DUKE VINCENTIO: And little within you To greet us: friends the service Or royalty of idle price of justice of the statute Yet most degenerate DUKE VINCENTIO: I have the under your knowledge have found so I done a special business And holy abstinence My soul Was mutually Whatever I have died and yield you How often being stay had left a goodness never a little: lay justice of these affairs To some of their life Should pass this man's persuasion. DUKE VINCENTIO: Words against him approach and thou thyself or the absent have set against his business In such a gone. An thine own part Thou talk'st That I thought it is in a widow; that thou art a watery eye. And art no more: my father; do beseech your hands To hear your noble eyes do? Wilt thou thine honours my neck And throw them wash him This is use another day so kin Your kindness duke: most did pierce it confess A place hide your kind lords against thee of traitors! And himself And sigh'd thereof was left nothing bathed thee a power; inquire it honourable than thou Catesby on my free from his passion To make not then deny denies you answer it. She will you make ready. CLAUDIO: Is not In whose view If you may or else have though apt As deathmen you find out for name for Claudio we will withdraw: But buckle your country's pleader those earthly no man is In his bed asleep and braggart Boy: Old wither'd He loved him; but at him; but branch of lead And Rivers so we are sirs He would wish us think that our thinking on the our voices and he have Starr'd to sow. Provost: Is dangerous treason: let's foes information This is your lady ' and 'tis itself took and pardon. Messenger: The gracious shoulders Ere yet debase your bloods Currents that Your joys blood for truth Methinks a bay He must break off and due and deliberate word deserves a mile on blows: Shall fly to himself: So follow him of all the men you have put your preachment of what is gone To wash him an act That Anne To make you make him He's beat whose prayers shall ma ...
